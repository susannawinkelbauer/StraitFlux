# %% [markdown]
# ## Download CMIP6 data from ESGF
# A short sample script how to download the CMIP6 data needed for `Examples.ipynb`
#
# There are multiple ways to search for and download data from ESGF (e.g. `esgf-pyclient`).<br>
# For most of those you'll need to **register** with one the the ESGF data portals (e.g. https://esgf-node.llnl.gov/projects/esgf-llnl/)
#
# The simplest way to download the data needed for `Examples.ipynb` is using `wget` (would not recommend if multiple different models and variables are needed):

# %%
import wget

# %% [markdown]
# Here we'd like to download the x- and y- velocities (uo and vo), temperatures (thetao), salinities (so) and vertical cell thicknesses (thkcello) for the CanESM5 model for 2001-2014:<br>
# First we'll specify the path were to save files, **make sure to have enough storage space!**

# %%
path = 'YOUR_PATH/'

# %% [markdown]
# Further, we'll have to specify an available node and the data files to finally use wget to download the files:

# %%
var=['uo','vo','thetao','so']
for i in var:
    node = 'http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/'+i+'/gn/v20190429/' #we'll use the esgf-data1.llnl.gov node
    file = i+'_Omon_CanESM5_historical_r1i1p1f1_gn_200101-201012.nc' #uo, vo, thetao and so files for the CanESM5 model for 2001-2010
    a = node + file
    b = path + file
    print(a)
    print(b)
    print('downloading...')
    wget.download(a,b)
# Out:
# http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/uo/gn/v20190429/uo_Omon_CanESM5_historical_r1i1p1f1_gn_200101-201012.nc
# /mnt/scratch/scratch/swinkelbauer/CMIP/uo_Omon_CanESM5_historical_r1i1p1f1_gn_200101-201012.nc
# downloading...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a241b0a878cb> in <module>
#       8     print(dwt)
#       9     print('downloading...')
# ---> 10     wget.download(dwf,dwt)
#
# ~/.local/lib/python3.8/site-packages/wget.py in download(url, out, bar)
#     524     else:
#     525         binurl = url
# --> 526     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#     527     filename = detect_filename(url, out, headers)
#     528     if outdir:
#
# /home/swd/anaconda3/lib/python3.8/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     274
#     275             while True:
# --> 276                 block = fp.read(bs)
#     277                 if not block:
#     278                     break
#
# /home/swd/anaconda3/lib/python3.8/http/client.py in read(self, amt)
#     453             # Amount is given, implement using readinto
#     454             b = bytearray(amt)
# --> 455             n = self.readinto(b)
#     456             return memoryview(b)[:n].tobytes()
#     457         else:
#
# /home/swd/anaconda3/lib/python3.8/http/client.py in readinto(self, b)
#     497         # connection, and the user is reading more bytes than will be provided
#     498         # (for example, reading in 1k chunks)
# --> 499         n = self.fp.readinto(b)
#     500         if not n and b:
#     501             # Ideally, we would raise IncompleteRead if the content-length
#
# /home/swd/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /home/swd/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /home/swd/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# We further need the exact vertical cell extents (thkcello):

# %%
node = 'http://esgf3.dkrz.de/thredds/fileServer/cmip6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Ofx/thkcello/gn/v20190429/' #we'll use the esgf-data1.llnl.gov node
file = 'thkcello_Ofx_CanESM5_historical_r1i1p1f1_gn.nc' #uo, vo, thetao and so files for the CanESM5 model for 2001-2010
a = node + file
b = path + file
print(a)
print(b)
print('downloading...')
wget.download(a,b)

# %% [markdown]
# **For downloading other files you can find the respective nodes and file names on the ESGF search interface (https://esgf-node.llnl.gov/search/cmip6/)**

# %% [markdown]
# ## Download Reanalyses data from OpenDAP <br>
# The last example uses GLORYS2V4 reanalysis data obtained via the Copernicus Marine Service.<br>
# To download the data on the native grids via OpenDAP you'll have to register at: https://marine.copernicus.eu/ <br>
# You may than proceed to download the needed data from the OpenDAP server (https://tds.mercator-ocean.fr/thredds3/glorys2v4/glorys2v4_dbb_02.html). <br>
# The following script shows the download of the x-velocity (vozocrtx) component (**again make sure to have enough storage space!**):

# %%
import xarray as xa
import requests as rq
from datetime import date, timedelta
import logging
from requests.adapters import HTTPAdapter, Retry

# %%
session = rq.Session()
session.auth = ("YOUR_USERNAME","YOUR_PASSWORD")

# %%
print('get data u')
storeu = xa.backends.PydapDataStore.open('http://tds.mercator-ocean.fr/thredds3/dodsC/glorys2v4-monthly-gridU?nav_lon[0:1:1020][0:1:1441],nav_lat[0:1:1020][0:1:1441],deptht[0:1:74],time_counter[0:1:347],vozocrtx[0:1:347][0:1:74][0:1:1020][0:1:1441]',session = session)
print('open data')
datapgnu = xa.open_dataset(storeu,decode_times=False).isel(time_counter=slice(0,12))
# Out:
# get data u
# open data
# Warning: ecCodes 2.21.0 or higher is recommended. You are running version 2.20.0

# %% [markdown]
# The time_counter is given as days since 1950-01-01 00:00:00, we can convert it using xarrays decode_cf:

# %%
datapgnu=xa.decode_cf(datapgnu)

# %% [markdown]
# Due to the size of the individual files we'll want to save monthly files:<br>
# Note: we use the slice option to select the individual months in order to keep the time_counter dimension!

# %%
#Specify were to save the data:
path='YOUR_PATH/'

# %%
for j in range(len(datapgnu.time_counter)):
    print(datapgnu.time_counter[j])
    datapgnu.sel(time_counter=slice(datapgnu.time_counter[j],datapgnu.time_counter[j])).to_netcdf(path+'GLORYS2V4_uo_'+str(datapgnu.time_counter[0].dt.year.values)+'-'+str(datapgnu.time_counter[0].dt.month.values)+'.nc')
# Out:
# <xarray.DataArray 'time_counter' ()>
# array('1993-01-15T00:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time_counter  datetime64[ns] 1993-01-15
# Attributes:
#     standard_name:  time
#     long_name:      Time axis
#     axis:           T
#     _ChunkSizes:    512
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     208             try:
# --> 209                 file = self._cache[self._key]
#     210             except KeyError:
#
# ~/.local/lib/python3.8/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      54         with self._lock:
# ---> 55             value = self._cache[key]
#      56             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/mnt/users/staff/swinkelbauer/PhD/calculations/CMIP/Plots/Test/YOUR_PATH/GLORYS2V4_uo_1993-1.nc',), 'a', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '40610684-c5c2-4d3e-8bb8-b0c0c886407d']
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-6-a89a01ddbea0> in <module>
#       1 for j in range(len(datapgnu.time_counter)):
#       2     print(datapgnu.time_counter[j])
# ----> 3     datapgnu.sel(time_counter=slice(datapgnu.time_counter[j],datapgnu.time_counter[j])).to_netcdf(path+'GLORYS2V4_uo_'+str(datapgnu.time_counter[0].dt.year.values)+'-'+str(datapgnu.time_counter[0].dt.month.values)+'.nc')
#
# ~/.local/lib/python3.8/site-packages/xarray/core/dataset.py in to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    1910         from xarray.backends.api import to_netcdf
#    1911
# -> 1912         return to_netcdf(  # type: ignore  # mypy cannot resolve the overloads:(
#    1913             self,
#    1914             path,
#
# ~/.local/lib/python3.8/site-packages/xarray/backends/api.py in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1213                 f"unrecognized option 'invalid_netcdf' for engine {engine}"
#    1214             )
# -> 1215     store = store_open(target, mode, format, group, **kwargs)
#    1216
#    1217     if unlimited_dims is None:
#
# ~/.local/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     380             netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     381         )
# --> 382         return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#     383
#     384     def _acquire(self, needs_lock=True):
#
# ~/.local/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in __init__(self, manager, group, mode, lock, autoclose)
#     327         self._group = group
#     328         self._mode = mode
# --> 329         self.format = self.ds.data_model
#     330         self._filename = self.ds.filepath()
#     331         self.is_remote = is_remote_uri(self._filename)
#
# ~/.local/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in ds(self)
#     389     @property
#     390     def ds(self):
# --> 391         return self._acquire()
#     392
#     393     def open_store_variable(self, name, var):
#
# ~/.local/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in _acquire(self, needs_lock)
#     383
#     384     def _acquire(self, needs_lock=True):
# --> 385         with self._manager.acquire_context(needs_lock) as root:
#     386             ds = _nc4_require_group(root, self._group, self._mode)
#     387         return ds
#
# /home/swd/anaconda3/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~/.local/lib/python3.8/site-packages/xarray/backends/file_manager.py in acquire_context(self, needs_lock)
#     195     def acquire_context(self, needs_lock=True):
#     196         """Context manager for acquiring a file."""
# --> 197         file, cached = self._acquire_with_cache_info(needs_lock)
#     198         try:
#     199             yield file
#
# ~/.local/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     213                     kwargs = kwargs.copy()
#     214                     kwargs["mode"] = self._mode
# --> 215                 file = self._opener(*self._args, **kwargs)
#     216                 if self._mode == "w":
#     217                     # ensure file doesn't get overridden when opened again
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# PermissionError: [Errno 13] Permission denied: '/mnt/users/staff/swinkelbauer/PhD/calculations/CMIP/Plots/Test/YOUR_PATH/GLORYS2V4_uo_1993-1.nc'

# %% [markdown]
# You may download the y-velocities (vomecrty), temperatures (votemper) and salinities (vosaline) the same way, for the cell thicknesses we've created a `mesh_e3t_field.nc`, which you may download from zenodo:

# %%
# download the cell thickness data
import urllib.request
import shutil

url = 'https://zenodo.org/records/10376250/files/'
file_name_z = 'mesh_e3t_field.nc'
with urllib.request.urlopen(url + file_name_z) as response, open(file_name_z, 'wb') as out_file:
    shutil.copyfileobj(response, out_file)

z = xa.open_dataset(file_name_z)

# %%
z.to_netcdf(path+'mesh_e3t_field.nc')
# Out:
# <xarray.Dataset>
# Dimensions:      (ncl1: 75, ncl2: 1021, ncl3: 1442)
# Dimensions without coordinates: ncl1, ncl2, ncl3
# Data variables:
#     e3t_0_field  (ncl1, ncl2, ncl3) float32 ...
